# %%
import pandas as pd
import os

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("SQLite Test (1).db")


sql_query = "SELECT * FROM dataset_1"

df = pd.read_sql(sql_query, conn)


conn.close()

# %%
conn

# %%
sql_query
# Out:
# 'SELECT * FROM dataset_1'

# %%
df
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny         55.0   2PM
# 1      No Urgent Place  Friend(s)   Sunny         80.0  10AM
# 2      No Urgent Place  Friend(s)   Sunny         80.0  10AM
# 3      No Urgent Place  Friend(s)   Sunny         80.0   2PM
# 4      No Urgent Place  Friend(s)   Sunny         80.0   2PM
# ...                ...        ...     ...          ...   ...
# 12839             None       None    None          NaN  None
# 12840             None       None    None          NaN  None
# 12841             None       None    None          NaN  None
# 12842             None       None    None          NaN  None
# 12843             None       None    None          NaN  None
#
#                       coupon expiration  gender   age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female    21  Unmarried partner  ...
# 1               Coffee House         2h  Female    21  Unmarried partner  ...
# 2      Carry out & Take away         2h  Female    21  Unmarried partner  ...
# 3               Coffee House         2h  Female    21  Unmarried partner  ...
# 4               Coffee House         1d  Female    21  Unmarried partner  ...
# ...                      ...        ...     ...   ...                ...  ...
# 12839                   None       None    None  None               None  ...
# 12840                   None       None    None  None               None  ...
# 12841                   None       None    None  None               None  ...
# 12842                   None       None    None  None               None  ...
# 12843                   None       None    None  None               None  ...
#
#        toCoupon_GEQ25min direction_same direction_opp    Y row_count Column1  \
# 0                    0.0            0.0           1.0  1.0       1.0     NaN
# 1                    0.0            0.0           1.0  0.0       2.0     NaN
# 2                    0.0            0.0           1.0  1.0       3.0     NaN
# 3                    0.0            0.0           1.0  0.0       4.0     NaN
# 4                    0.0            0.0           1.0  0.0       5.0     NaN
# ...                  ...            ...           ...  ...       ...     ...
# 12839                NaN            NaN           NaN  NaN       NaN   209.0
# 12840                NaN            NaN           NaN  NaN       NaN   210.0
# 12841                NaN            NaN           NaN  NaN       NaN   211.0
# 12842                NaN            NaN           NaN  NaN       NaN   212.0
# 12843                NaN            NaN           NaN  NaN       NaN   213.0
#
#                           Table                        Row  \
# 0                          None                       None
# 1                          None                       None
# 2                          None                       None
# 3                          None                       None
# 4                          None                       None
# ...                         ...                        ...
# 12839  previous_application.csv             DAYS_FIRST_DUE
# 12840  previous_application.csv  DAYS_LAST_DUE_1ST_VERSION
# 12841  previous_application.csv              DAYS_LAST_DUE
# 12842  previous_application.csv           DAYS_TERMINATION
# 12843  previous_application.csv  NFLAG_INSURED_ON_APPROVAL
#
#                                              Description  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 12839  Relative to application date of current applic...
# 12840  Relative to application date of current applic...
# 12841  Relative to application date of current applic...
# 12842  Relative to application date of current applic...
# 12843  Did the client requested insurance during the ...
#
#                                      Special
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 12839  time only relative to the application
# 12840  time only relative to the application
# 12841  time only relative to the application
# 12842  time only relative to the application
# 12843
#
# [12844 rows x 32 columns]

# %%
df[['weather' ,'temperature' ]]
# Out:
#       weather  temperature
# 0       Sunny         55.0
# 1       Sunny         80.0
# 2       Sunny         80.0
# 3       Sunny         80.0
# 4       Sunny         80.0
# ...       ...          ...
# 12839    None          NaN
# 12840    None          NaN
# 12841    None          NaN
# 12842    None          NaN
# 12843    None          NaN
#
# [12844 rows x 2 columns]

# %%
df.head(10)
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny         55.0   2PM
# 1  No Urgent Place  Friend(s)   Sunny         80.0  10AM
# 2  No Urgent Place  Friend(s)   Sunny         80.0  10AM
# 3  No Urgent Place  Friend(s)   Sunny         80.0   2PM
# 4  No Urgent Place  Friend(s)   Sunny         80.0   2PM
# 5  No Urgent Place  Friend(s)   Sunny         80.0   6PM
# 6  No Urgent Place  Friend(s)   Sunny         55.0   2PM
# 7  No Urgent Place     Kid(s)   Sunny         80.0  10AM
# 8  No Urgent Place     Kid(s)   Sunny         80.0  10AM
# 9  No Urgent Place     Kid(s)   Sunny         80.0  10AM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
# 5        Restaurant(<20)         2h  Female  21  Unmarried partner  ...
# 6  Carry out & Take away         1d  Female  21  Unmarried partner  ...
# 7        Restaurant(<20)         2h  Female  21  Unmarried partner  ...
# 8  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 9                    Bar         1d  Female  21  Unmarried partner  ...
#
#    toCoupon_GEQ25min direction_same direction_opp    Y row_count Column1  \
# 0                0.0            0.0           1.0  1.0       1.0     NaN
# 1                0.0            0.0           1.0  0.0       2.0     NaN
# 2                0.0            0.0           1.0  1.0       3.0     NaN
# 3                0.0            0.0           1.0  0.0       4.0     NaN
# 4                0.0            0.0           1.0  0.0       5.0     NaN
# 5                0.0            0.0           1.0  1.0       6.0     NaN
# 6                0.0            0.0           1.0  1.0       7.0     NaN
# 7                0.0            0.0           1.0  1.0       8.0     NaN
# 8                0.0            0.0           1.0  1.0       9.0     NaN
# 9                0.0            0.0           1.0  0.0      10.0     NaN
#
#   Table   Row Description Special
# 0  None  None        None    None
# 1  None  None        None    None
# 2  None  None        None    None
# 3  None  None        None    None
# 4  None  None        None    None
# 5  None  None        None    None
# 6  None  None        None    None
# 7  None  None        None    None
# 8  None  None        None    None
# 9  None  None        None    None
#
# [10 rows x 32 columns]

# %%
df['passanger'].unique()
# Out:
# array(['Alone', 'Friend(s)', 'Kid(s)', 'Partner', None], dtype=object)

# %%
df[df['destination']=='Home']
# Out:
#       destination passanger weather  temperature  time                 coupon  \
# 13           Home     Alone   Sunny         55.0   6PM                    Bar
# 14           Home     Alone   Sunny         55.0   6PM      Restaurant(20-50)
# 15           Home     Alone   Sunny         80.0   6PM           Coffee House
# 35           Home     Alone   Sunny         55.0   6PM                    Bar
# 36           Home     Alone   Sunny         55.0   6PM      Restaurant(20-50)
# ...           ...       ...     ...          ...   ...                    ...
# 12675        Home     Alone   Snowy         30.0  10PM           Coffee House
# 12676        Home     Alone   Sunny         80.0   6PM      Restaurant(20-50)
# 12677        Home   Partner   Sunny         30.0   6PM        Restaurant(<20)
# 12678        Home   Partner   Sunny         30.0  10PM        Restaurant(<20)
# 12679        Home   Partner   Rainy         55.0   6PM  Carry out & Take away
#
#       expiration  gender age      maritalStatus  ...  toCoupon_GEQ25min  \
# 13            1d  Female  21  Unmarried partner  ...                0.0
# 14            1d  Female  21  Unmarried partner  ...                0.0
# 15            2h  Female  21  Unmarried partner  ...                0.0
# 35            1d    Male  21             Single  ...                0.0
# 36            1d    Male  21             Single  ...                0.0
# ...          ...     ...  ..                ...  ...                ...
# 12675         2h    Male  26             Single  ...                0.0
# 12676         1d    Male  26             Single  ...                0.0
# 12677         1d    Male  26             Single  ...                1.0
# 12678         2h    Male  26             Single  ...                0.0
# 12679         1d    Male  26             Single  ...                0.0
#
#       direction_same direction_opp    Y row_count Column1 Table   Row  \
# 13               1.0           0.0  1.0      14.0     NaN  None  None
# 14               0.0           1.0  1.0      15.0     NaN  None  None
# 15               0.0           1.0  0.0      16.0     NaN  None  None
# 35               1.0           0.0  1.0      36.0     NaN  None  None
# 36               0.0           1.0  0.0      37.0     NaN  None  None
# ...              ...           ...  ...       ...     ...   ...   ...
# 12675            0.0           1.0  0.0   12676.0     NaN  None  None
# 12676            1.0           0.0  1.0   12677.0     NaN  None  None
# 12677            0.0           1.0  1.0   12678.0     NaN  None  None
# 12678            1.0           0.0  0.0   12679.0     NaN  None  None
# 12679            1.0           0.0  1.0   12680.0     NaN  None  None
#
#       Description Special
# 13           None    None
# 14           None    None
# 15           None    None
# 35           None    None
# 36           None    None
# ...           ...     ...
# 12675        None    None
# 12676        None    None
# 12677        None    None
# 12678        None    None
# 12679        None    None
#
# [3237 rows x 32 columns]

# %%
df.sort_values('coupon')
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 11702             Home    Partner   Sunny         30.0  10PM    Bar
# 9930   No Urgent Place      Alone   Snowy         30.0   2PM    Bar
# 10632             Home      Alone   Rainy         55.0   6PM    Bar
# 7997   No Urgent Place  Friend(s)   Rainy         55.0  10PM    Bar
# 11166             Work      Alone   Snowy         30.0   7AM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12839             None       None    None          NaN  None   None
# 12840             None       None    None          NaN  None   None
# 12841             None       None    None          NaN  None   None
# 12842             None       None    None          NaN  None   None
# 12843             None       None    None          NaN  None   None
#
#       expiration  gender     age      maritalStatus  ...  toCoupon_GEQ25min  \
# 11702         2h  Female  50plus    Married partner  ...                1.0
# 9930          1d  Female      21             Single  ...                0.0
# 10632         1d    Male      21             Single  ...                1.0
# 7997          2h    Male      26  Unmarried partner  ...                0.0
# 11166         1d  Female      41    Married partner  ...                1.0
# ...          ...     ...     ...                ...  ...                ...
# 12839       None    None    None               None  ...                NaN
# 12840       None    None    None               None  ...                NaN
# 12841       None    None    None               None  ...                NaN
# 12842       None    None    None               None  ...                NaN
# 12843       None    None    None               None  ...                NaN
#
#       direction_same direction_opp    Y row_count Column1  \
# 11702            0.0           1.0  0.0   11703.0     NaN
# 9930             0.0           1.0  0.0    9931.0     NaN
# 10632            0.0           1.0  0.0   10633.0     NaN
# 7997             0.0           1.0  1.0    7998.0     NaN
# 11166            0.0           1.0  0.0   11167.0     NaN
# ...              ...           ...  ...       ...     ...
# 12839            NaN           NaN  NaN       NaN   209.0
# 12840            NaN           NaN  NaN       NaN   210.0
# 12841            NaN           NaN  NaN       NaN   211.0
# 12842            NaN           NaN  NaN       NaN   212.0
# 12843            NaN           NaN  NaN       NaN   213.0
#
#                           Table                        Row  \
# 11702                      None                       None
# 9930                       None                       None
# 10632                      None                       None
# 7997                       None                       None
# 11166                      None                       None
# ...                         ...                        ...
# 12839  previous_application.csv             DAYS_FIRST_DUE
# 12840  previous_application.csv  DAYS_LAST_DUE_1ST_VERSION
# 12841  previous_application.csv              DAYS_LAST_DUE
# 12842  previous_application.csv           DAYS_TERMINATION
# 12843  previous_application.csv  NFLAG_INSURED_ON_APPROVAL
#
#                                              Description  \
# 11702                                               None
# 9930                                                None
# 10632                                               None
# 7997                                                None
# 11166                                               None
# ...                                                  ...
# 12839  Relative to application date of current applic...
# 12840  Relative to application date of current applic...
# 12841  Relative to application date of current applic...
# 12842  Relative to application date of current applic...
# 12843  Did the client requested insurance during the ...
#
#                                      Special
# 11702                                   None
# 9930                                    None
# 10632                                   None
# 7997                                    None
# 11166                                   None
# ...                                      ...
# 12839  time only relative to the application
# 12840  time only relative to the application
# 12841  time only relative to the application
# 12842  time only relative to the application
# 12843
#
# [12844 rows x 32 columns]

# %%
df.rename(columns={'destination':'Destination'},inplace=True)

# %%
df
# Out:
#            Destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny         55.0   2PM
# 1      No Urgent Place  Friend(s)   Sunny         80.0  10AM
# 2      No Urgent Place  Friend(s)   Sunny         80.0  10AM
# 3      No Urgent Place  Friend(s)   Sunny         80.0   2PM
# 4      No Urgent Place  Friend(s)   Sunny         80.0   2PM
# ...                ...        ...     ...          ...   ...
# 12839             None       None    None          NaN  None
# 12840             None       None    None          NaN  None
# 12841             None       None    None          NaN  None
# 12842             None       None    None          NaN  None
# 12843             None       None    None          NaN  None
#
#                       coupon expiration  gender   age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female    21  Unmarried partner  ...
# 1               Coffee House         2h  Female    21  Unmarried partner  ...
# 2      Carry out & Take away         2h  Female    21  Unmarried partner  ...
# 3               Coffee House         2h  Female    21  Unmarried partner  ...
# 4               Coffee House         1d  Female    21  Unmarried partner  ...
# ...                      ...        ...     ...   ...                ...  ...
# 12839                   None       None    None  None               None  ...
# 12840                   None       None    None  None               None  ...
# 12841                   None       None    None  None               None  ...
# 12842                   None       None    None  None               None  ...
# 12843                   None       None    None  None               None  ...
#
#        toCoupon_GEQ25min direction_same direction_opp    Y row_count Column1  \
# 0                    0.0            0.0           1.0  1.0       1.0     NaN
# 1                    0.0            0.0           1.0  0.0       2.0     NaN
# 2                    0.0            0.0           1.0  1.0       3.0     NaN
# 3                    0.0            0.0           1.0  0.0       4.0     NaN
# 4                    0.0            0.0           1.0  0.0       5.0     NaN
# ...                  ...            ...           ...  ...       ...     ...
# 12839                NaN            NaN           NaN  NaN       NaN   209.0
# 12840                NaN            NaN           NaN  NaN       NaN   210.0
# 12841                NaN            NaN           NaN  NaN       NaN   211.0
# 12842                NaN            NaN           NaN  NaN       NaN   212.0
# 12843                NaN            NaN           NaN  NaN       NaN   213.0
#
#                           Table                        Row  \
# 0                          None                       None
# 1                          None                       None
# 2                          None                       None
# 3                          None                       None
# 4                          None                       None
# ...                         ...                        ...
# 12839  previous_application.csv             DAYS_FIRST_DUE
# 12840  previous_application.csv  DAYS_LAST_DUE_1ST_VERSION
# 12841  previous_application.csv              DAYS_LAST_DUE
# 12842  previous_application.csv           DAYS_TERMINATION
# 12843  previous_application.csv  NFLAG_INSURED_ON_APPROVAL
#
#                                              Description  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 12839  Relative to application date of current applic...
# 12840  Relative to application date of current applic...
# 12841  Relative to application date of current applic...
# 12842  Relative to application date of current applic...
# 12843  Did the client requested insurance during the ...
#
#                                      Special
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 12839  time only relative to the application
# 12840  time only relative to the application
# 12841  time only relative to the application
# 12842  time only relative to the application
# 12843
#
# [12844 rows x 32 columns]

# %%
df.groupby('occupation').size().to_frame('count').reset_index()
# Out:
#                                    occupation  count
# 0                  Architecture & Engineering    175
# 1    Arts Design Entertainment Sports & Media    629
# 2   Building & Grounds Cleaning & Maintenance     44
# 3                        Business & Financial    544
# 4                 Community & Social Services    241
# 5                     Computer & Mathematical   1408
# 6                   Construction & Extraction    154
# 7                  Education&Training&Library    943
# 8                  Farming Fishing & Forestry     43
# 9          Food Preparation & Serving Related    298
# 10       Healthcare Practitioners & Technical    244
# 11                         Healthcare Support    242
# 12          Installation Maintenance & Repair    133
# 13                                      Legal    219
# 14               Life Physical Social Science    170
# 15                                 Management    838
# 16            Office & Administrative Support    639
# 17                    Personal Care & Service    175
# 18                     Production Occupations    110
# 19                         Protective Service    175
# 20                                    Retired    495
# 21                            Sales & Related   1093
# 22                                    Student   1584
# 23           Transportation & Material Moving    218
# 24                                 Unemployed   1870

# %%
df.groupby('weather')['temperature'].mean().to_frame('avg_temp').reset_index()
# Out:
#   weather   avg_temp
# 0   Rainy  55.000000
# 1   Snowy  30.000000
# 2   Sunny  68.946271

# %%
df.groupby('weather')['temperature'].size().to_frame('count_temp').reset_index()
# Out:
#   weather  count_temp
# 0   Rainy        1210
# 1   Snowy        1405
# 2   Sunny       10069

# %%
df.groupby('weather')['temperature'].nunique().to_frame('count_distinct_temp').reset_index()
# Out:
#   weather  count_distinct_temp
# 0   Rainy                    1
# 1   Snowy                    1
# 2   Sunny                    3

# %%
df.groupby('weather')['temperature'].sum().to_frame('sum_temp').reset_index()
# Out:
#   weather  sum_temp
# 0   Rainy   66550.0
# 1   Snowy   42150.0
# 2   Sunny  694220.0

# %%
df.groupby('weather')['temperature'].min().to_frame('min_temp').reset_index()
# Out:
#   weather  min_temp
# 0   Rainy      55.0
# 1   Snowy      30.0
# 2   Sunny      30.0

# %%
df.groupby('weather')['temperature'].max().to_frame('max_temp').reset_index()
# Out:
#   weather  max_temp
# 0   Rainy      55.0
# 1   Snowy      30.0
# 2   Sunny      80.0

# %%
df.groupby('occupation').filter(lambda x: x['occupation'].iloc[0] ==
'Student').groupby('occupation').size()
# Out:
# occupation
# Student    1584
# dtype: int64

# %%
pd.concat([df, df1])['destination'].drop_duplicates()
# Out:
# 0      NaN
# 0    UNION
# Name: destination, dtype: object

# %%
df1=pd.read_csv(r"C:\Users\Dell i7\Desktop\table_to_union.csv")
df1
# Out:
#   destination passanger weather  temperature time           coupon expiration  \
# 0       UNION     UNION   UNION           55  2PM  Restaurant(<20)         1d
#
#    gender  age      maritalStatus  ...  CarryAway RestaurantLessThan20  \
# 0  Female   21  Unmarried partner  ...        NaN                  4~8
#
#   Restaurant20To50 toCoupon_GEQ5min  toCoupon_GEQ15min toCoupon_GEQ25min  \
# 0              1~3                1                  0                 0
#
#   direction_same  direction_opp  Y row_count
# 0              0              1  1         1
#
# [1 rows x 27 columns]

# %%
pd.concat([df, df1])['destination'].drop_duplicates()
# Out:
# 0      NaN
# 0    UNION
# Name: destination, dtype: object

# %%
df2=pd.read_csv(r'C:\\Users\\Dell i7\\Desktop\\table_join.csv')

# %%
df2
# Out:
#    time part_of_day
# 0   2PM   Afternoon
# 1  10AM     Morning
# 2   6PM     Evening
# 3   7AM     Morning
# 4  10PM       Night

# %%
df
# Out:
#            Destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny         55.0   2PM
# 1      No Urgent Place  Friend(s)   Sunny         80.0  10AM
# 2      No Urgent Place  Friend(s)   Sunny         80.0  10AM
# 3      No Urgent Place  Friend(s)   Sunny         80.0   2PM
# 4      No Urgent Place  Friend(s)   Sunny         80.0   2PM
# ...                ...        ...     ...          ...   ...
# 12839             None       None    None          NaN  None
# 12840             None       None    None          NaN  None
# 12841             None       None    None          NaN  None
# 12842             None       None    None          NaN  None
# 12843             None       None    None          NaN  None
#
#                       coupon expiration  gender   age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female    21  Unmarried partner  ...
# 1               Coffee House         2h  Female    21  Unmarried partner  ...
# 2      Carry out & Take away         2h  Female    21  Unmarried partner  ...
# 3               Coffee House         2h  Female    21  Unmarried partner  ...
# 4               Coffee House         1d  Female    21  Unmarried partner  ...
# ...                      ...        ...     ...   ...                ...  ...
# 12839                   None       None    None  None               None  ...
# 12840                   None       None    None  None               None  ...
# 12841                   None       None    None  None               None  ...
# 12842                   None       None    None  None               None  ...
# 12843                   None       None    None  None               None  ...
#
#        toCoupon_GEQ25min direction_same direction_opp    Y row_count Column1  \
# 0                    0.0            0.0           1.0  1.0       1.0     NaN
# 1                    0.0            0.0           1.0  0.0       2.0     NaN
# 2                    0.0            0.0           1.0  1.0       3.0     NaN
# 3                    0.0            0.0           1.0  0.0       4.0     NaN
# 4                    0.0            0.0           1.0  0.0       5.0     NaN
# ...                  ...            ...           ...  ...       ...     ...
# 12839                NaN            NaN           NaN  NaN       NaN   209.0
# 12840                NaN            NaN           NaN  NaN       NaN   210.0
# 12841                NaN            NaN           NaN  NaN       NaN   211.0
# 12842                NaN            NaN           NaN  NaN       NaN   212.0
# 12843                NaN            NaN           NaN  NaN       NaN   213.0
#
#                           Table                        Row  \
# 0                          None                       None
# 1                          None                       None
# 2                          None                       None
# 3                          None                       None
# 4                          None                       None
# ...                         ...                        ...
# 12839  previous_application.csv             DAYS_FIRST_DUE
# 12840  previous_application.csv  DAYS_LAST_DUE_1ST_VERSION
# 12841  previous_application.csv              DAYS_LAST_DUE
# 12842  previous_application.csv           DAYS_TERMINATION
# 12843  previous_application.csv  NFLAG_INSURED_ON_APPROVAL
#
#                                              Description  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 12839  Relative to application date of current applic...
# 12840  Relative to application date of current applic...
# 12841  Relative to application date of current applic...
# 12842  Relative to application date of current applic...
# 12843  Did the client requested insurance during the ...
#
#                                      Special
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 12839  time only relative to the application
# 12840  time only relative to the application
# 12841  time only relative to the application
# 12842  time only relative to the application
# 12843
#
# [12844 rows x 32 columns]

# %%
pd.merge(df, df2[['time', 'part_of_day']], on='time', how='inner')[['Destination', 'time', 'part_of_day']]
# Out:
#            Destination  time part_of_day
# 0      No Urgent Place   2PM   Afternoon
# 1      No Urgent Place   2PM   Afternoon
# 2      No Urgent Place   2PM   Afternoon
# 3      No Urgent Place   2PM   Afternoon
# 4      No Urgent Place   2PM   Afternoon
# ...                ...   ...         ...
# 12679  No Urgent Place  10PM       Night
# 12680  No Urgent Place  10PM       Night
# 12681             Home  10PM       Night
# 12682             Home  10PM       Night
# 12683             Home  10PM       Night
#
# [12684 rows x 3 columns]

# %%
df[df['passanger'] == 'Alone'][['Destination', 'passanger']]
# Out:
#            Destination passanger
# 0      No Urgent Place     Alone
# 13                Home     Alone
# 14                Home     Alone
# 15                Home     Alone
# 16                Work     Alone
# ...                ...       ...
# 12676             Home     Alone
# 12680             Work     Alone
# 12681             Work     Alone
# 12682             Work     Alone
# 12683             Work     Alone
#
# [7305 rows x 2 columns]

# %%
df11[df11['weather'].str.startswith('Sun')]
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 10064             Home      Alone   Sunny           30   6PM
# 10065             Home      Alone   Sunny           80   6PM
# 10066             Home    Partner   Sunny           30   6PM
# 10067             Home    Partner   Sunny           30  10PM
# 10068             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# 2      Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3               Coffee House         2h  Female  21  Unmarried partner  ...
# 4               Coffee House         1d  Female  21  Unmarried partner  ...
# ...                      ...        ...     ...  ..                ...  ...
# 10064  Carry out & Take away         1d    Male  26             Single  ...
# 10065      Restaurant(20-50)         1d    Male  26             Single  ...
# 10066        Restaurant(<20)         1d    Male  26             Single  ...
# 10067        Restaurant(<20)         2h    Male  26             Single  ...
# 10068      Restaurant(20-50)         2h    Male  26             Single  ...
#
#        toCoupon_GEQ25min direction_same direction_opp  Y row_count Column1  \
# 0                      0              0             1  1         1     NaN
# 1                      0              0             1  0         2     NaN
# 2                      0              0             1  1         3     NaN
# 3                      0              0             1  0         4     NaN
# 4                      0              0             1  0         5     NaN
# ...                  ...            ...           ... ..       ...     ...
# 10064                  0              0             1  0     12674     NaN
# 10065                  0              1             0  1     12677     NaN
# 10066                  1              0             1  1     12678     NaN
# 10067                  0              1             0  0     12679     NaN
# 10068                  0              1             0  0     12684     NaN
#
#       Table Row Description Special
# 0       NaN NaN         NaN     NaN
# 1       NaN NaN         NaN     NaN
# 2       NaN NaN         NaN     NaN
# 3       NaN NaN         NaN     NaN
# 4       NaN NaN         NaN     NaN
# ...     ...  ..         ...     ...
# 10064   NaN NaN         NaN     NaN
# 10065   NaN NaN         NaN     NaN
# 10066   NaN NaN         NaN     NaN
# 10067   NaN NaN         NaN     NaN
# 10068   NaN NaN         NaN     NaN
#
# [10069 rows x 32 columns]

# %%
df['weather'].isnull().count()
# Out:
# 12844

# %%
df11=pd.read_csv(r'C:\Users\Dell i7\Desktop\abc.csv')

# %%
df[(df['temperature'] >= 29) & (df['temperature'] <= 75)]['temperature'].unique()
# Out:
# array([55., 30.])

# %%
df[df['occupation'].isin(['Sales & Related', 'Management'])][['occupation']]
# Out:
#             occupation
# 193    Sales & Related
# 194    Sales & Related
# 195    Sales & Related
# 196    Sales & Related
# 197    Sales & Related
# ...                ...
# 12679  Sales & Related
# 12680  Sales & Related
# 12681  Sales & Related
# 12682  Sales & Related
# 12683  Sales & Related
#
# [1931 rows x 1 columns]
