# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
t = pd.read_csv(r'C:\\Users\\Dell i7\\Downloads\\data prepro\\train.csv')

# %%
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
t.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
del t ["Name"]

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
del t ["Ticket"]

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
del t ["Fare"]

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0            1         0       3    male  22.0      1      0   NaN        S
# 1            2         1       1  female  38.0      1      0   C85        C
# 2            3         1       3  female  26.0      0      0   NaN        S
# 3            4         1       1  female  35.0      1      0  C123        S
# 4            5         0       3    male  35.0      0      0   NaN        S

# %%
del t ["Cabin"]

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %%
def getNumber(str):
    if str=="male":
        return 1
    else:
    
        return 2
t["Gender"]=t["Sex"].apply(getNumber)

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3    male  22.0      1      0        S       1
# 1            2         1       1  female  38.0      1      0        C       2
# 2            3         1       3  female  26.0      0      0        S       2
# 3            4         1       1  female  35.0      1      0        S       2
# 4            5         0       3    male  35.0      0      0        S       1

# %%
del t ["Sex"]

# %%
t .head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender
# 0            1         0       3  22.0      1      0        S       1
# 1            2         1       1  38.0      1      0        C       2
# 2            3         1       3  26.0      0      0        S       2
# 3            4         1       1  35.0      1      0        S       2
# 4            5         0       3  35.0      0      0        S       1

# %%
t.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# dtype: int64

# %%
meanS= t[t .Survived==1].Age.mean()
meanS
# Out:
# 28.343689655172415

# %%
t ["age"]=np.where(pd.isnull(t .Age)& t["Survived"]==1 , meanS ,t ["Age"])

# %%
t .head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
t.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age            125
# dtype: int64

# %%
meanNS=t[t.Survived==0].Age.mean()

# %%
meanNS
# Out:
# 30.62617924528302

# %%
t['age'].fillna(meanNS ,inplace=True)
t.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Embarked  Gender   age
# 0            1         0       3  22.0      1      0        S       1  22.0
# 1            2         1       1  38.0      1      0        C       2  38.0
# 2            3         1       3  26.0      0      0        S       2  26.0
# 3            4         1       1  35.0      1      0        S       2  35.0
# 4            5         0       3  35.0      0      0        S       1  35.0

# %%
t.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Embarked         2
# Gender           0
# age              0
# dtype: int64

# %%
del t ["Age"]
t.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
SurvivedQ= t[t.Embarked=='Q'][t.Survived==1].shape[0]
SurvivedC =t[t.Embarked=='C'][t.Survived==1].shape[0]
SurvivedS =t[t.Embarked=='S'][t.Survived==1].shape[0]

print(SurvivedQ)
print(SurvivedC)
print(SurvivedS)
# Out:
# 30
# 93
# 217
# C:\Users\Dell i7\AppData\Local\Temp\ipykernel_6320\435427654.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SurvivedQ= t[t.Embarked=='Q'][t.Survived==1].shape[0]
# C:\Users\Dell i7\AppData\Local\Temp\ipykernel_6320\435427654.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SurvivedC =t[t.Embarked=='C'][t.Survived==1].shape[0]
# C:\Users\Dell i7\AppData\Local\Temp\ipykernel_6320\435427654.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SurvivedS =t[t.Embarked=='S'][t.Survived==1].shape[0]

# %%
SurvivedQ= t[t.Embarked=='Q'][t.Survived==0].shape[0]
SurvivedC =t[t.Embarked=='C'][t.Survived==0].shape[0]
SurvivedS =t[t.Embarked=='S'][t.Survived==0].shape[0]

print(SurvivedQ)
print(SurvivedC)
print(SurvivedS)
# Out:
# 47
# 75
# 427
# C:\Users\Dell i7\AppData\Local\Temp\ipykernel_6320\2153499366.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SurvivedQ= t[t.Embarked=='Q'][t.Survived==0].shape[0]
# C:\Users\Dell i7\AppData\Local\Temp\ipykernel_6320\2153499366.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SurvivedC =t[t.Embarked=='C'][t.Survived==0].shape[0]
# C:\Users\Dell i7\AppData\Local\Temp\ipykernel_6320\2153499366.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SurvivedS =t[t.Embarked=='S'][t.Survived==0].shape[0]

# %%
t.dropna(inplace=True)
t.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
t.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# SibSp          0
# Parch          0
# Embarked       0
# Gender         0
# age            0
# dtype: int64

# %%
t.rename(columns={'age':'Age'}, inplace=True)
t.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Gender   Age
# 0            1         0       3      1      0        S       1  22.0
# 1            2         1       1      1      0        C       2  38.0
# 2            3         1       3      0      0        S       2  26.0
# 3            4         1       1      1      0        S       2  35.0
# 4            5         0       3      0      0        S       1  35.0

# %%
t.rename(columns={"Gender":"Sex"} ,inplace=True)
t.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age
# 0            1         0       3      1      0        S    1  22.0
# 1            2         1       1      1      0        C    2  38.0
# 2            3         1       3      0      0        S    2  26.0
# 3            4         1       1      1      0        S    2  35.0
# 4            5         0       3      0      0        S    1  35.0

# %%
def getEmb(str):
    if str=="S":
        return 1
    elif str=='Q':
        return 2
    else:
        return 3
t["Embark"]=t["Embarked"].apply(getEmb)
t.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch Embarked  Sex   Age  Embark
# 0            1         0       3      1      0        S    1  22.0       1
# 1            2         1       1      1      0        C    2  38.0       3
# 2            3         1       3      0      0        S    2  26.0       1
# 3            4         1       1      1      0        S    2  35.0       1
# 4            5         0       3      0      0        S    1  35.0       1

# %%
del t["Embarked"]
t.rename(columns={'Embark':'Embarked'}, inplace=True)
t.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch  Sex   Age  Embarked
# 0            1         0       3      1      0    1  22.0         1
# 1            2         1       1      1      0    2  38.0         3
# 2            3         1       3      0      0    2  26.0         1
# 3            4         1       1      1      0    2  35.0         1
# 4            5         0       3      0      0    1  35.0         1

# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
males=(t['Sex']==1).sum()
females=(t['Sex']==2).sum()
print(males)
print(females)
p=[males,females]
plt.pie(p,
       labels =['males' ,'females'],
       colors =['green','yellow'],
       explode= (0.15 ,0),
       startangle = 0)
plt.axis('equal')
plt.show()
# Out:
# 577
# 312

# %%
maleS =t[t.Sex==1][t.Survived==1].shape[0]
print(maleS)
maleN =t[t.Sex==1][t.Survived==0].shape[0]
print(maleN)
femaleS =t[t.Sex==2][t.Survived==1].shape[0]
print(femaleS)
femaleN =t[t.Sex==2][t.Survived==0].shape[0]
print(femaleN)
# Out:
# 109
# 468
# 231
# 81
# C:\Users\Dell i7\AppData\Local\Temp\ipykernel_6320\4291950109.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   maleS =t[t.Sex==1][t.Survived==1].shape[0]
# C:\Users\Dell i7\AppData\Local\Temp\ipykernel_6320\4291950109.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   maleN =t[t.Sex==1][t.Survived==0].shape[0]
# C:\Users\Dell i7\AppData\Local\Temp\ipykernel_6320\4291950109.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   femaleS =t[t.Sex==2][t.Survived==1].shape[0]
# C:\Users\Dell i7\AppData\Local\Temp\ipykernel_6320\4291950109.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   femaleN =t[t.Sex==2][t.Survived==0].shape[0]

# %%
charts=[maleS]

# %%
chart=[maleS,maleN,femaleS,femaleN]
colors=['lightskyblue','yellowgreen','Yellow','Orange']
labels=["Survived male","Not Survived male","Survived female","Not Survived female"]
explode=[0,0.05,0,0.1]
plt.pie(chart,labels=labels,colors=colors,explode=explode,startangle=100,counterclock=False,autopct="%.2f%%")
plt.axis("equal")
plt.show()
